# %% [markdown]
# <a href="https://colab.research.google.com/github/catalannegrasse/una/blob/main/unab_pa_tp_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
